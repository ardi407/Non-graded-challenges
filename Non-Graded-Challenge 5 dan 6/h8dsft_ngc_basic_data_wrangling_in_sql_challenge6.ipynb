# %%
from google.colab import auth
from google.cloud import bigquery
import pandas as pd

auth.authenticate_user()
project_id = "ngc-6-400305" # <-- sesuaikan dengan project_id kalian
client = bigquery.Client(project=project_id)

# put your query here
query = """
SELECT *
FROM bigquery-public-data.austin_bikeshare.bikeshare_trips
"""
      # Project ID             #dataset       #table
# Set up the query
query_job = client.query(query).to_dataframe()
query_job
# Out:
#           trip_id          subscriber_type bike_id bike_type  \
# 0        16796969  U.T. Student Membership     265   classic
# 1        26479330       Student Membership   2122B  electric
# 2        26415048       Student Membership   19847  electric
# 3        26537395          Pay-as-you-ride   16456  electric
# 4        26539287       Student Membership   19287  electric
# ...           ...                      ...     ...       ...
# 2011910  27204360                  Local31   17751  electric
# 2011911  27627680                 Local365   19198  electric
# 2011912  26558059                  Local31   21508  electric
# 2011913  26449124       Student Membership   17460  electric
# 2011914  26512329       Student Membership   21541  electric
#
#                        start_time  start_station_id    start_station_name  \
# 0       2018-03-06 00:27:55+00:00              3798  21st & Speedway @PCL
# 1       2022-04-23 10:41:39+00:00              7189              28th/Rio
# ...

# %%
query = """
SELECT table_name, COUNT(table_name) AS jumlah
FROM `bigquery-public-data.austin_bikeshare.INFORMATION_SCHEMA.TABLES`
GROUP BY table_name
"""

# Set up the query
query_job = client.query(query).to_dataframe()
query_job
# Out:
#            table_name  jumlah
# 0  bikeshare_stations       1
# 1     bikeshare_trips       1

# %% [markdown]
# Terdapat 2 tables dalam austin_bikeshare dataset, yaitu:
# 1. bikeshare_stations
# 2. bikeshare_trips

# %%
query = """
SELECT COUNT(data_type) as string_data_type
FROM `bigquery-public-data.austin_bikeshare.INFORMATION_SCHEMA.COLUMNS`
WHERE table_name = 'bikeshare_stations' AND data_type = 'STRING'
"""
# WHERE table_name = 'bikeshare_stations';
# Set up the query
query_job = client.query(query).to_dataframe()
query_job
# Out:
#    string_data_type
# 0                 7

# %% [markdown]
# **Terdapat 7 Column** yang memiliki datatype STRING.

# %%
query = """
SELECT *
FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
WHERE bike_id IS NOT NULL AND duration_minutes > 1000 AND
      subscriber_type = 'Walk Up' AND end_station_name = 'Stolen';
"""

# Set up the query
query_job = client.query(query).to_dataframe()
query_job
# Out:
#     trip_id subscriber_type bike_id bike_type                start_time  \
# 0  16898448         Walk Up    1857   classic 2018-03-18 22:51:20+00:00
# 1  16863172         Walk Up    1795   classic 2018-03-14 21:23:26+00:00
# 2  17151360         Walk Up    1899   classic 2018-04-21 15:29:10+00:00
# 3  13564817         Walk Up     393   classic 2017-01-28 04:57:28+00:00
# 4  11712091         Walk Up     327   classic 2016-09-02 06:37:15+00:00
# 5  11714202         Walk Up     122   classic 2016-09-02 09:00:56+00:00
# 6  13857913         Walk Up     135   classic 2017-02-26 14:32:45+00:00
# 7  13555129         Walk Up     578   classic 2017-01-27 01:35:26+00:00
#
#    start_station_id                                 start_station_name  \
# 0              2501                                        5th & Bowie
# 1              2542                                     Plaza Saltillo
# 2              2563                             Davis at Rainey Street
# ...
